# %%
# --- Reading and writing a text file ---
with open("example.txt", "w") as f:
    f.write("Hello, this is Day 11 of #100DaysOfPython!")

with open("example.txt", "r") as f:
    content = f.read()
    print("Text file content:", content)

# --- Working with JSON ---
import json

data = {"name": "Aman", "course": "Python", "day": 11}
with open("data.json", "w") as json_file:
    json.dump(data, json_file)

with open("data.json", "r") as json_file:
    loaded = json.load(json_file)
    print("JSON data loaded:", loaded)
# Out:
# Text file content: Hello, this is Day 11 of #100DaysOfPython!
# JSON data loaded: {'name': 'Aman', 'course': 'Python', 'day': 11}

# %%
# --- Working with CSV ---
import csv

rows = [
    ["Name", "Score"],
    ["Aman", 90],
    ["Ramesh", 85]
]

with open("scores.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(rows)

with open("scores.csv", "r") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        print("CSV row:", row)
# Out:
# CSV row: ['Name', 'Score']
# CSV row: ['Aman', '90']
# CSV row: ['Ramesh', '85']
